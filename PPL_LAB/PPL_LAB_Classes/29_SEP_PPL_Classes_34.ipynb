# %%
#import library , import modules

import math
import pandas as pd
print(math.sqrt(500))
# Out:
# 22.360679774997898

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import Mym
Mym.sayhello("Rohit")
# Out:
# hello Rohit

# %%
from Mym import Person1
print(person1['age'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Mym import Person1
#       2 print(person1['age'])
#
# ImportError: cannot import name 'Person1' from 'Mym' (c:\Users\legen\Desktop\Right\NITJ_AI\PPL_LAB\PPL_LAB_Classes\Mym.py)

# %%
# from math *
from math import sqrt,pi,factorial
from math sqrt as squartroot
print(squartroot(81))
# Out:
#   Cell In[3], line 3
#     from math sqrt as squartroot
#               ^
# SyntaxError: invalid syntax

# %%
#command line argument
import sys
print(sys argv)

#c:\python34> python main.py hello world
#o/p 'numpy.py 'hello','world'
# Out:
#   Cell In[4], line 3
#     print(sys argv)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
